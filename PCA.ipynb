# %% [markdown]
# <a href="https://colab.research.google.com/github/MaheenZaheer/Machine-Learning/blob/main/PCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
import pandas as pd
import numpy as np
import random

# %%
x, y_true = make_blobs(n_samples=500,n_features=5,centers=3,cluster_std=0.5, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
le = StandardScaler()
x = le.fit_transform(x)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)
x_pca = pca.fit_transform(x)

# %%
df_pca = pd.DataFrame(x_pca, columns=['PC1', 'PC2'])
df_pca['y'] = y_true
df_pca.head()
# Out:
#         PC1       PC2  y
# 0 -0.635937 -2.075976  2
# 1 -0.586716 -1.779427  2
# 2 -1.687859  1.230763  0
# 3  2.034850  0.623957  1
# 4 -0.405117 -2.020266  2

# %%
sns.scatterplot(data=df_pca, x='PC1', y='PC2', hue='y')
#
# Out:
# <Axes: xlabel='PC1', ylabel='PC2'>
