# %% [markdown]
# <a href="https://colab.research.google.com/github/MaheenZaheer/Machine-Learning/blob/main/Ensemble_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import StackingClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
df = sns.load_dataset("iris")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
x = df.drop(["species"],axis = 1)
y = df['species']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y_encoded, test_size=0.2, random_state=42)

# %% [markdown]
# Stacking

# %%
base_learner = [
    ("KNeignourestNeighbor", KNeighborsClassifier(n_neighbors=17)),
    ("LogisticRegression", LogisticRegression()),
    ("NaiveBayes", GaussianNB())
]

# %%
meta_learner = LogisticRegression()

# %%
model = StackingClassifier(estimators=base_learner, final_estimator=meta_learner,cv = 5)
model
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('KNeignourestNeighbor',
#                                 KNeighborsClassifier(n_neighbors=17)),
#                                ('LogisticRegression', LogisticRegression()),
#                                ('NaiveBayes', GaussianNB())],
#                    final_estimator=LogisticRegression())

# %%
eval = model.fit(X_train, y_train)
eval
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('KNeignourestNeighbor',
#                                 KNeighborsClassifier(n_neighbors=17)),
#                                ('LogisticRegression', LogisticRegression()),
#                                ('NaiveBayes', GaussianNB())],
#                    final_estimator=LogisticRegression())

# %%
y_pred = eval.predict(X_test)

# %%
acc = accuracy_score(y_test, y_pred)
acc
# Out:
# 1.0

# %% [markdown]
# Bagging in terms of random forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %%
model_rf = RandomForestClassifier(n_estimators=1000)

# %%
model_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=1000)

# %%
y_pred = model_rf.predict(X_test)

# %%
acc = accuracy_score(y_test, y_pred)
acc
# Out:
# 0.98

# %% [markdown]
# Boosting

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
model_ada = AdaBoostClassifier(n_estimators=100)

# %%
model_ada.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(n_estimators=100)

# %%
y_pred = model_ada.predict(X_test)

# %%
acc = accuracy_score(y_test, y_pred)
acc
# Out:
# 0.94

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
model_gra = GradientBoostingClassifier(n_estimators=1000)

# %%
model_gra.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(n_estimators=1000)

# %%
y_pred = model_gra.predict(X_test)

# %%
acc = accuracy_score(y_test, y_pred)
acc
# Out:
# 0.98

# %%
from xgboost import XGBClassifier

# %%
model_xg = XGBClassifier(n_estimators=100,)

# %%
y_train_encoded = le.fit_transform(y_train)

# %%
model_xg.fit(X_train, y_train_encoded)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred = model_xg.predict(X_test)

# %%
y_test_encoded = le.transform(y_test)

# %%
acc = accuracy_score(y_test_encoded, y_pred)
acc
# Out:
# 0.98
